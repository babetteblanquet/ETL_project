# %%
import pandas as pd
import datetime as dt
from sqlalchemy import create_engine

# %% [markdown]
# ## Extract CSV into DataFrames¶

# %%
csv_file = "2- CSV/Original_CSV/VIF2019_Pop_Hholds_Dws_ASGS_2036_households_types.csv"
df = pd.read_csv(csv_file)
df.head()
# Out:
#   Victoria in Future 2019 (VIF2019) Population and Household Projections  \
# 0                                             Jun-19
# 1  Contact: David Sykes (DELWP) 03 8683 0936 | da...
# 2                                                NaN
# 3                                                NaN
# 4                       Households by household type
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 0        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 2        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 3        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 4        NaN        NaN        NaN  ...         NaN         NaN         NaN
#
#    Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 44
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 45 columns]

# %%
#Identifying the row containing the column names
df.iloc[8]
# Out:
# Victoria in Future 2019 (VIF2019) Population and Household Projections                             GCCSA
# Unnamed: 1                                                                                           SA4
# Unnamed: 2                                                                                           SA3
# Unnamed: 3                                                                                           SA2
# Unnamed: 4                                                                                     Area Type
# Unnamed: 5                                                                                     Area Name
# Unnamed: 6                                                                   Couple family with children
# Unnamed: 7                                                                Couple family without children
# Unnamed: 8                                                                             One-parent family
# Unnamed: 9                                                                                  Other family
# Unnamed: 10                                                                              Group household
# Unnamed: 11                                                                                  Lone person
# Unnamed: 12                                                                          All Household Types
# Unnamed: 13                                                                                          NaN
# Unnamed: 14                                                                  Couple family with children
# Unnamed: 15                                                               Couple family without children
# Unnamed: 16                                                                            One-parent family
# Unnamed: 17                                                                                 Other family
# Unnamed: 18                                                                              Group household
# Unnamed: 19                                                                                  Lone person
# Unnamed: 20                                                                          All Household Types
# Unnamed: 21                                                                                          NaN
# Unnamed: 22                                                                  Couple family with children
# Unnamed: 23                                                               Couple family without children
# Unnamed: 24                                                                            One-parent family
# Unnamed: 25                                                                                 Other family
# Unnamed: 26                                                                              Group household
# Unnamed: 27                                                                                  Lone person
# Unnamed: 28                                                                          All Household Types
# Unnamed: 29                                                                                          NaN
# Unnamed: 30                                                                  Couple family with children
# Unnamed: 31                                                               Couple family without children
# Unnamed: 32                                                                            One-parent family
# Unnamed: 33                                                                                 Other family
# Unnamed: 34                                                                              Group household
# Unnamed: 35                                                                                  Lone person
# Unnamed: 36                                                                          All Household Types
# Unnamed: 37                                                                                          NaN
# Unnamed: 38                                                                  Couple family with children
# Unnamed: 39                                                               Couple family without children
# Unnamed: 40                                                                            One-parent family
# Unnamed: 41                                                                                 Other family
# Unnamed: 42                                                                              Group household
# Unnamed: 43                                                                                  Lone person
# Unnamed: 44                                                                          All Household Types
# Name: 8, dtype: object

# %%
#set row 8 as the new columns' head
df.columns = df.iloc[8]
df.head()
# Out:
# 8                                              GCCSA  SA4  SA3  SA2 Area Type  \
# 0                                             Jun-19  NaN  NaN  NaN       NaN
# 1  Contact: David Sykes (DELWP) 03 8683 0936 | da...  NaN  NaN  NaN       NaN
# 2                                                NaN  NaN  NaN  NaN       NaN
# 3                                                NaN  NaN  NaN  NaN       NaN
# 4                       Households by household type  NaN  NaN  NaN       NaN
#
# 8 Area Name  Couple family with children Couple family without children  \
# 0       NaN                          NaN                            NaN
# 1       NaN                          NaN                            NaN
# 2       NaN                          NaN                            NaN
# 3       NaN                          NaN                            NaN
# 4       NaN                          NaN                            NaN
#
# 8 One-parent family Other family  ... Lone person All Household Types NaN  \
# 0               NaN          NaN  ...         NaN                 NaN NaN
# 1               NaN          NaN  ...         NaN                 NaN NaN
# 2               NaN          NaN  ...         NaN                 NaN NaN
# 3               NaN          NaN  ...         NaN                 NaN NaN
# 4               NaN          NaN  ...         NaN                 NaN NaN
#
# 8  Couple family with children Couple family without children  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
# 8 One-parent family Other family Group household Lone person  \
# 0               NaN          NaN             NaN         NaN
# 1               NaN          NaN             NaN         NaN
# 2               NaN          NaN             NaN         NaN
# 3               NaN          NaN             NaN         NaN
# 4               NaN          NaN             NaN         NaN
#
# 8 All Household Types
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 45 columns]

# %%
#Drop unnecessary rows
new_df = df.iloc[10:472,:]
new_df
# Out:
# 8    GCCSA  SA4    SA3        SA2 Area Type            Area Name  \
# 10   2RVIC  201  20101  201011001       SA2            Alfredton
# 11   2RVIC  201  20101  201011002       SA2             Ballarat
# 12   2RVIC  201  20101  201011003       SA2     Ballarat - North
# 13   2RVIC  201  20101  201011004       SA2     Ballarat - South
# 14   2RVIC  201  20101  201011005       SA2            Buninyong
# ..     ...  ...    ...        ...       ...                  ...
# 467  2RVIC  217  21703  217031476       SA2                Otway
# 468  2RVIC  217  21704  217041477       SA2         Moyne - East
# 469  2RVIC  217  21704  217041478       SA2         Moyne - West
# 470  2RVIC  217  21704  217041479       SA2  Warrnambool - North
# 471  2RVIC  217  21704  217041480       SA2  Warrnambool - South
#
# 8    Couple family with children Couple family without children  \
# 10                         1,657                          1,121
# 11                         1,270                          1,377
# 12                         2,653                          2,585
# 13                         2,310                          2,488
# 14                           988                            797
# ..                           ...                            ...
# 467                          326                            559
# 468                          848                            843
# 469                        1,173                          1,299
# 470                        2,518                          2,400
# 471                        1,327                          1,577
#
# 8   One-parent family Other family  ... Lone person All Household Types NaN  \
# 10                508           30  ...       1,756               8,805 NaN
# 11                532           46  ...       2,068               5,762 NaN
# 12              1,107           90  ...       3,954              11,936 NaN
# 13              1,587          152  ...       4,815              13,354 NaN
# 14                227           14  ...         717               3,394 NaN
# ..                ...          ...  ...         ...                 ...  ..
# 467               154            2  ...         679               1,819 NaN
# 468               226           24  ...         817               2,989 NaN
# 469               328           31  ...       1,308               4,725 NaN
# 470             1,070           83  ...       3,121              10,731 NaN
# 471               554           52  ...       2,251               6,251 NaN
#
# 8    Couple family with children Couple family without children  \
# 10                         3,935                          2,725
# 11                         1,226                          1,640
# 12                         2,959                          3,365
# 13                         2,817                          3,168
# 14                         1,239                          1,173
# ..                           ...                            ...
# 467                          315                            601
# 468                          900                            985
# 469                        1,379                          1,645
# 470                        3,054                          3,134
# 471                        1,268                          1,897
#
# 8   One-parent family Other family Group household Lone person  \
# 10              1,175           70             324       2,102
# 11                545           46             305       2,183
# 12              1,309          102             563       4,230
# 13              1,986          177             797       5,124
# 14                295           18             121         805
# ..                ...          ...             ...         ...
# 467               175            3              55         686
# 468               263           26              57         863
# 469               411           42             112       1,410
# 470             1,303           96             387       3,351
# 471               571           52             273       2,362
#
# 8   All Household Types
# 10               10,332
# 11                5,944
# 12               12,527
# 13               14,068
# 14                3,651
# ..                  ...
# 467               1,834
# 468               3,094
# 469               5,001
# 470              11,326
# 471               6,422
#
# [462 rows x 45 columns]

# %%
df = new_df.reset_index(drop=True)
df
# Out:
# 8    GCCSA  SA4    SA3        SA2 Area Type            Area Name  \
# 0    2RVIC  201  20101  201011001       SA2            Alfredton
# 1    2RVIC  201  20101  201011002       SA2             Ballarat
# 2    2RVIC  201  20101  201011003       SA2     Ballarat - North
# 3    2RVIC  201  20101  201011004       SA2     Ballarat - South
# 4    2RVIC  201  20101  201011005       SA2            Buninyong
# ..     ...  ...    ...        ...       ...                  ...
# 457  2RVIC  217  21703  217031476       SA2                Otway
# 458  2RVIC  217  21704  217041477       SA2         Moyne - East
# 459  2RVIC  217  21704  217041478       SA2         Moyne - West
# 460  2RVIC  217  21704  217041479       SA2  Warrnambool - North
# 461  2RVIC  217  21704  217041480       SA2  Warrnambool - South
#
# 8    Couple family with children Couple family without children  \
# 0                          1,657                          1,121
# 1                          1,270                          1,377
# 2                          2,653                          2,585
# 3                          2,310                          2,488
# 4                            988                            797
# ..                           ...                            ...
# 457                          326                            559
# 458                          848                            843
# 459                        1,173                          1,299
# 460                        2,518                          2,400
# 461                        1,327                          1,577
#
# 8   One-parent family Other family  ... Lone person All Household Types NaN  \
# 0                 508           30  ...       1,756               8,805 NaN
# 1                 532           46  ...       2,068               5,762 NaN
# 2               1,107           90  ...       3,954              11,936 NaN
# 3               1,587          152  ...       4,815              13,354 NaN
# 4                 227           14  ...         717               3,394 NaN
# ..                ...          ...  ...         ...                 ...  ..
# 457               154            2  ...         679               1,819 NaN
# 458               226           24  ...         817               2,989 NaN
# 459               328           31  ...       1,308               4,725 NaN
# 460             1,070           83  ...       3,121              10,731 NaN
# 461               554           52  ...       2,251               6,251 NaN
#
# 8    Couple family with children Couple family without children  \
# 0                          3,935                          2,725
# 1                          1,226                          1,640
# 2                          2,959                          3,365
# 3                          2,817                          3,168
# 4                          1,239                          1,173
# ..                           ...                            ...
# 457                          315                            601
# 458                          900                            985
# 459                        1,379                          1,645
# 460                        3,054                          3,134
# 461                        1,268                          1,897
#
# 8   One-parent family Other family Group household Lone person  \
# 0               1,175           70             324       2,102
# 1                 545           46             305       2,183
# 2               1,309          102             563       4,230
# 3               1,986          177             797       5,124
# 4                 295           18             121         805
# ..                ...          ...             ...         ...
# 457               175            3              55         686
# 458               263           26              57         863
# 459               411           42             112       1,410
# 460             1,303           96             387       3,351
# 461               571           52             273       2,362
#
# 8   All Household Types
# 0                10,332
# 1                 5,944
# 2                12,527
# 3                14,068
# 4                 3,651
# ..                  ...
# 457               1,834
# 458               3,094
# 459               5,001
# 460              11,326
# 461               6,422
#
# [462 rows x 45 columns]

# %% [markdown]
# ## Preparing CSV for the year 2016

# %%
#Select columns for the 2016 data
df_2016 = df.iloc[:,[3,5,6,7,8,9,10,11,12]]
df_2016.head()
# Out:
# 8        SA2         Area Name Couple family with children  \
# 0  201011001         Alfredton                       1,657
# 1  201011002          Ballarat                       1,270
# 2  201011003  Ballarat - North                       2,653
# 3  201011004  Ballarat - South                       2,310
# 4  201011005         Buninyong                         988
#
# 8 Couple family without children One-parent family Other family  \
# 0                          1,121               508           30
# 1                          1,377               532           46
# 2                          2,585             1,107           90
# 3                          2,488             1,587          152
# 4                            797               227           14
#
# 8 Group household Lone person All Household Types
# 0             142         813               4,272
# 1             335       1,782               5,341
# 2             506       3,117              10,058
# 3             701       3,874              11,111
# 4             103         477               2,606

# %%
#Add a column year with the value 2016
df_2016.insert(0, 'Year', '2016-06-30')
#Convert the column Year to datetime
df_2016['Year'] = pd.to_datetime(df_2016.Year)
#Checking the types of data in the dataframe
df_2016.dtypes
# Out:
# C:\Users\ianli\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 8
# Year                              datetime64[ns]
# SA2                                       object
# Area Name                                 object
# Couple family with children               object
# Couple family without children            object
# One-parent family                         object
# Other family                              object
# Group household                           object
# Lone person                               object
# All Household Types                       object
# dtype: object

# %% [markdown]
# ## Preparing CSV for the year 2021

# %%
#Select columns for the 2021 data
df_2021 = df.iloc[:,[3,5,14,15,16,17,18,19,20]]
df_2021.head()
# Out:
# 8        SA2         Area Name Couple family with children  \
# 0  201011001         Alfredton                       2,193
# 1  201011002          Ballarat                       1,233
# 2  201011003  Ballarat - North                       2,762
# 3  201011004  Ballarat - South                       2,455
# 4  201011005         Buninyong                       1,046
#
# 8 Couple family without children One-parent family Other family  \
# 0                          1,531               649           42
# 1                          1,439               524           45
# 2                          2,861             1,153           94
# 3                          2,722             1,683          159
# 4                            914               245           15
#
# 8 Group household Lone person All Household Types
# 0             191       1,097               5,704
# 1             314       1,835               5,389
# 2             516       3,426              10,812
# 3             723       4,222              11,964
# 4             102         557               2,879

# %%
#Add a column year with the value 2021
df_2021.insert(0, 'Year', '2021-06-30')
#Convert the column Year to datetime
df_2021['Year'] = pd.to_datetime(df_2021.Year)
#Checking the types of data in the dataframe
df_2021.dtypes
# Out:
# C:\Users\ianli\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 8
# Year                              datetime64[ns]
# SA2                                       object
# Area Name                                 object
# Couple family with children               object
# Couple family without children            object
# One-parent family                         object
# Other family                              object
# Group household                           object
# Lone person                               object
# All Household Types                       object
# dtype: object

# %% [markdown]
# ## Preparing CSV for the year 2026¶

# %%
#Select columns for the 2026 data
df_2026 = df.iloc[:,[3,5,22,23,24,25,26,27,28]]
df_2026.head()
# Out:
# 8        SA2         Area Name Couple family with children  \
# 0  201011001         Alfredton                       2,769
# 1  201011002          Ballarat                       1,229
# 2  201011003  Ballarat - North                       2,832
# 3  201011004  Ballarat - South                       2,594
# 4  201011005         Buninyong                       1,113
#
# 8 Couple family without children One-parent family Other family  \
# 0                          1,943               813           52
# 1                          1,519               527           45
# 2                          3,054             1,192           95
# 3                          2,882             1,771          161
# 4                          1,011               254           16
#
# 8 Group household Lone person All Household Types
# 0             238       1,417               7,232
# 1             305       1,956               5,580
# 2             516       3,686              11,375
# 3             727       4,522              12,657
# 4             110         631               3,134

# %%
#Add a column year with the value 2026
df_2026.insert(0, 'Year', '2026-06-30')
#Convert the column Year to datetime
df_2026['Year'] = pd.to_datetime(df_2026.Year)
#Checking the types of data in the dataframe
df_2026.dtypes
# Out:
# C:\Users\ianli\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 8
# Year                              datetime64[ns]
# SA2                                       object
# Area Name                                 object
# Couple family with children               object
# Couple family without children            object
# One-parent family                         object
# Other family                              object
# Group household                           object
# Lone person                               object
# All Household Types                       object
# dtype: object

# %% [markdown]
# ## Preparing CSV for the year 2031¶

# %%
#Select columns for the 2031 data
df_2031 = df.iloc[:,[3,5,30,31,32,33,34,35,36]]
df_2031.head()
# Out:
# 8        SA2         Area Name Couple family with children  \
# 0  201011001         Alfredton                       3,364
# 1  201011002          Ballarat                       1,225
# 2  201011003  Ballarat - North                       2,895
# 3  201011004  Ballarat - South                       2,720
# 4  201011005         Buninyong                       1,167
#
# 8 Couple family without children One-parent family Other family  \
# 0                          2,343               989           63
# 1                          1,588               533           44
# 2                          3,212             1,240           99
# 3                          3,023             1,870          169
# 4                          1,097               274           18
#
# 8 Group household Lone person All Household Types
# 0             290       1,756               8,805
# 1             304       2,068               5,762
# 2             535       3,954              11,936
# 3             757       4,815              13,354
# 4             121         717               3,394

# %%
#Add a column year with the value 2031
df_2031.insert(0, 'Year', '2031-06-30')
#Convert the column Year to datetime
df_2031['Year'] = pd.to_datetime(df_2031.Year)
df_2031.dtypes
# Out:
# C:\Users\ianli\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 8
# Year                              datetime64[ns]
# SA2                                       object
# Area Name                                 object
# Couple family with children               object
# Couple family without children            object
# One-parent family                         object
# Other family                              object
# Group household                           object
# Lone person                               object
# All Household Types                       object
# dtype: object

# %% [markdown]
# ## Preparing CSV for the year 2036

# %%
#Select columns for the 2036 data
df_2036 = df.iloc[:,[3,5,38,39,40,41,42,43,44]]
df_2036.head()
# Out:
# 8        SA2         Area Name Couple family with children  \
# 0  201011001         Alfredton                       3,935
# 1  201011002          Ballarat                       1,226
# 2  201011003  Ballarat - North                       2,959
# 3  201011004  Ballarat - South                       2,817
# 4  201011005         Buninyong                       1,239
#
# 8 Couple family without children One-parent family Other family  \
# 0                          2,725             1,175           70
# 1                          1,640               545           46
# 2                          3,365             1,309          102
# 3                          3,168             1,986          177
# 4                          1,173               295           18
#
# 8 Group household Lone person All Household Types
# 0             324       2,102              10,332
# 1             305       2,183               5,944
# 2             563       4,230              12,527
# 3             797       5,124              14,068
# 4             121         805               3,651

# %%
#Add a column year with the value 2036
df_2036.insert(0, 'Year', '2036-06-30')
#Convert the column Year to datetime
df_2036['Year'] = pd.to_datetime(df_2036.Year)
df_2036.dtypes
# Out:
# C:\Users\ianli\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 8
# Year                              datetime64[ns]
# SA2                                       object
# Area Name                                 object
# Couple family with children               object
# Couple family without children            object
# One-parent family                         object
# Other family                              object
# Group household                           object
# Lone person                               object
# All Household Types                       object
# dtype: object

# %% [markdown]
# ## Concatenate the 5 dataframes together into a master file

# %%
#Concatenate the five dataframes into one called "master"
frames = [df_2016, df_2021, df_2026, df_2031, df_2036]
master = pd.concat(frames)

# %%
#Rename some columns:
master = master.rename(columns={"Year": "Date",
                                "SA2": "SA2 code",
                                "Area Name": "SA2 name"})
master.head()
# Out:
# 8       Date   SA2 code          SA2 name Couple family with children  \
# 0 2016-06-30  201011001         Alfredton                       1,657
# 1 2016-06-30  201011002          Ballarat                       1,270
# 2 2016-06-30  201011003  Ballarat - North                       2,653
# 3 2016-06-30  201011004  Ballarat - South                       2,310
# 4 2016-06-30  201011005         Buninyong                         988
#
# 8 Couple family without children One-parent family Other family  \
# 0                          1,121               508           30
# 1                          1,377               532           46
# 2                          2,585             1,107           90
# 3                          2,488             1,587          152
# 4                            797               227           14
#
# 8 Group household Lone person All Household Types
# 0             142         813               4,272
# 1             335       1,782               5,341
# 2             506       3,117              10,058
# 3             701       3,874              11,111
# 4             103         477               2,606

# %% [markdown]
# ## Exploratory analysis

# %%
#Checking the type of data
master.dtypes
# Out:
# 8
# Date                              datetime64[ns]
# SA2 code                                  object
# SA2 name                                  object
# Couple family with children               object
# Couple family without children            object
# One-parent family                         object
# Other family                              object
# Group household                           object
# Lone person                               object
# All Household Types                       object
# dtype: object

# %%
#def master(column):
    #master['column'] = master['column'].str.replace(',','')
    #master['column'] = master['column'].astype(int)
    #return master['column']

# %%
#master("Lone person")

# %%
#Converting strings into integer for the relevant columns:
master['Couple family with children'] = master['Couple family with children'].str.replace(',','')
master['Couple family with children'] = master['Couple family with children'].astype(int)
master['Couple family without children'] = master['Couple family without children'].str.replace(',','')
master['Couple family without children'] = master['Couple family without children'].astype(int)
master['One-parent family'] = master['One-parent family'].str.replace(',','')
master['One-parent family'] = master['One-parent family'].astype(int)
master['Other family'] = master['Other family'].str.replace(',','')
master['Other family'] = master['Other family'].astype(int)
master['Group household'] = master['Group household'].str.replace(',','')
master['Group household'] = master['Group household'].astype(int)
master['Lone person'] = master['Lone person'].str.replace(',','')
master['Lone person'] = master['Lone person'].astype(int)
master['All Household Types'] = master['All Household Types'].str.replace(',','')
master['All Household Types'] = master['All Household Types'].astype(int)
master.head()
# Out:
# 8       Date   SA2 code          SA2 name  Couple family with children  \
# 0 2016-06-30  201011001         Alfredton                         1657
# 1 2016-06-30  201011002          Ballarat                         1270
# 2 2016-06-30  201011003  Ballarat - North                         2653
# 3 2016-06-30  201011004  Ballarat - South                         2310
# 4 2016-06-30  201011005         Buninyong                          988
#
# 8  Couple family without children  One-parent family  Other family  \
# 0                            1121                508            30
# 1                            1377                532            46
# 2                            2585               1107            90
# 3                            2488               1587           152
# 4                             797                227            14
#
# 8  Group household  Lone person  All Household Types
# 0              142          813                 4272
# 1              335         1782                 5341
# 2              506         3117                10058
# 3              701         3874                11111
# 4              103          477                 2606

# %%
master.dtypes
# Out:
# 8
# Date                              datetime64[ns]
# SA2 code                                  object
# SA2 name                                  object
# Couple family with children                int32
# Couple family without children             int32
# One-parent family                          int32
# Other family                               int32
# Group household                            int32
# Lone person                                int32
# All Household Types                        int32
# dtype: object

# %%
#Drop Null values
master = master.dropna(how="any")
master.count()
# Out:
# 8
# Date                              2310
# SA2 code                          2310
# SA2 name                          2310
# Couple family with children       2310
# Couple family without children    2310
# One-parent family                 2310
# Other family                      2310
# Group household                   2310
# Lone person                       2310
# All Household Types               2310
# dtype: int64

# %%
#Drop duplicates:
master = master.drop_duplicates(subset=['Date', 'SA2 code','All Household Types'])
master.count()
# Out:
# 8
# Date                              2310
# SA2 code                          2310
# SA2 name                          2310
# Couple family with children       2310
# Couple family without children    2310
# One-parent family                 2310
# Other family                      2310
# Group household                   2310
# Lone person                       2310
# All Household Types               2310
# dtype: int64

# %%
#Checking the quality of the data by sorting the total of 'All Household Types':
SA2group = master.groupby(["SA2 code","SA2 name"])
SA2group_df = pd.DataFrame(SA2group["All Household Types"].sum())
sort_master = SA2group_df.sort_values(by=["All Household Types"])
sort_master.head(10)
# Out:
#                               All Household Types
# SA2 code  SA2 name
# 205031092 Wilsons Promontory                    0
# 205021083 Lake King                             0
# 205021080 Alps - East                           0
# 210011227 Essendon Airport                      0
# 205051099 Alps - West                           0
# 208031192 Moorabbin Airport                     0
# 206041127 West Melbourne                        2
# 208031184 Braeside                             55
# 205031088 French Island                       234
# 210051248 Melbourne Airport                   445

# %% [markdown]
# We can see some SA2 areas have no household in these areas. As an example, people might be working at Essendon Airport but no one is living there. We will keep those SA2 areas as they remain important if we want to map the Household Types in Victoria and understand where the population live.

# %%
# #Reorder columns in dataframe to prepare for load db
# cols = list(master.columns.values)
# cols = ['SA2 code', 'SA2 name', 'Date','Couple family with children', 'Couple family without children', 'One-parent family', 'Other family', 'Group household', 'Lone person', 'All Household Types']
# master = master[cols]
# master.head()

# %%
#Rename some columns:
master = master.rename(columns={"SA2 code": "sa2_code",
                                "SA2 name": "sa2_name",
                                "Date": "stat_date",
                                "Couple family with children": "couple_family_with_children",
                                "Couple family without children": "couple_family_without_children",
                                "One-parent family": "one_parent_family",
                                "Other family": "other_family",
                                "Group household": "group_household",
                                "Lone person": "lone_person",
                                "All Household Types": "all_household_types",
                               })
master.head()
# Out:
# 8  stat_date   sa2_code          sa2_name  couple_family_with_children  \
# 0 2016-06-30  201011001         Alfredton                         1657
# 1 2016-06-30  201011002          Ballarat                         1270
# 2 2016-06-30  201011003  Ballarat - North                         2653
# 3 2016-06-30  201011004  Ballarat - South                         2310
# 4 2016-06-30  201011005         Buninyong                          988
#
# 8  couple_family_without_children  one_parent_family  other_family  \
# 0                            1121                508            30
# 1                            1377                532            46
# 2                            2585               1107            90
# 3                            2488               1587           152
# 4                             797                227            14
#
# 8  group_household  lone_person  all_household_types
# 0              142          813                 4272
# 1              335         1782                 5341
# 2              506         3117                10058
# 3              701         3874                11111
# 4              103          477                 2606

# %%
#Save Master file as CSV to be loaded in our database:
master.to_csv('2- CSV/master_households_types_1.csv')
master.dtypes
# Out:
# 8
# stat_date                         datetime64[ns]
# sa2_code                                  object
# sa2_name                                  object
# couple_family_with_children                int32
# couple_family_without_children             int32
# one_parent_family                          int32
# other_family                               int32
# group_household                            int32
# lone_person                                int32
# all_household_types                        int32
# dtype: object

# %%
rds_connection_string = "postgres:<password>@localhost:5432/population_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['households_type']

# %%
master.to_sql(name='households_type', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from households_type', con=engine).head()
# Out:
#     stat_date   sa2_code          sa2_name  couple_family_with_children  \
# 0  2016-06-30  201011001         Alfredton                         1657
# 1  2016-06-30  201011002          Ballarat                         1270
# 2  2016-06-30  201011003  Ballarat - North                         2653
# 3  2016-06-30  201011004  Ballarat - South                         2310
# 4  2016-06-30  201011005         Buninyong                          988
#
#    couple_family_without_children  one_parent_family  other_family  \
# 0                            1121                508            30
# 1                            1377                532            46
# 2                            2585               1107            90
# 3                            2488               1587           152
# 4                             797                227            14
#
#    group_household  lone_person  all_household_types
# 0              142          813                 4272
# 1              335         1782                 5341
# 2              506         3117                10058
# 3              701         3874                11111
# 4              103          477                 2606
