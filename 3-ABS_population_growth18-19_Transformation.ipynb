# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Extract Population 2018-2019 data into DataFrame

# %%
# Read CSV
df = pd.read_csv('2- CSV/Original_CSV/32180ds0001_2018-19.csv')
df.head()
# Out:
#                      Australian Bureau of Statistics Unnamed: 1 Unnamed: 2  \
# 0      3218.0  Regional Population Growth, Australia        NaN        NaN
# 1  Released at 11.30am (Canberra time) 25 March 2020        NaN        NaN
# 2  Table 2. Estimated Resident Population, Statis...        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 12 Unnamed: 13  Unnamed: 14 Unnamed: 15  \
# 0        NaN  ...         NaN         NaN          NaN         NaN
# 1        NaN  ...         NaN         NaN          NaN         NaN
# 2        NaN  ...         NaN         NaN          NaN         NaN
# 3        NaN  ...         NaN         NaN          NaN         NaN
# 4        NaN  ...         NaN  ERP change          NaN         NaN
#
#                                Unnamed: 16  Unnamed: 17 Unnamed: 18  \
# 0                                      NaN          NaN         NaN
# 1                                      NaN          NaN         NaN
# 2                                      NaN          NaN         NaN
# 3                                      NaN          NaN         NaN
# 4  Components of population change 2018-19          NaN         NaN
#
#   Unnamed: 19 Unnamed: 20  Unnamed: 21
# 0         NaN         NaN          NaN
# 1         NaN         NaN          NaN
# 2         NaN         NaN          NaN
# 3         NaN         NaN          NaN
# 4         NaN         NaN          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Transformation of dataframe

# %%
#Identifying the row containing the column names - row index 6:
df.iloc[6]
# Out:
#             Australian Bureau of Statistics       S/T code
# Unnamed: 1                                        S/T name
# Unnamed: 2                                      GCCSA code
# Unnamed: 3                                      GCCSA name
# Unnamed: 4                                        SA4 code
# Unnamed: 5                                        SA4 name
# Unnamed: 6                                        SA3 code
# Unnamed: 7                                        SA3 name
# Unnamed: 8                                        SA2 code
# Unnamed: 9                                        SA2 name
# Unnamed: 10                                            no.
# Unnamed: 11                                            no.
# Unnamed: 12                                            NaN
# Unnamed: 13                                            no.
# Unnamed: 14                                              %
# Unnamed: 15                                            NaN
# Unnamed: 16                                            no.
# Unnamed: 17                                            no.
# Unnamed: 18                                            no.
# Unnamed: 19                                            NaN
# Unnamed: 20                                            km2
# Unnamed: 21                                    persons/km2
# Name: 6, dtype: object

# %%
#Renaming some column names via iloc as there are too many columns titled "no."
df.iloc[6,10]= 'Population_2018'
df.iloc[6,11]='Population_2019'
df.iloc[6,13]='Population_growth'
df.iloc[6,16]='Natural Increase'
df.iloc[6,17]='Net Internal Migration'
df.iloc[6,18]='Net Overseas Migration'

# %%
#Checking data has been replaced
df.iloc[6]
# Out:
#             Australian Bureau of Statistics                  S/T code
# Unnamed: 1                                                   S/T name
# Unnamed: 2                                                 GCCSA code
# Unnamed: 3                                                 GCCSA name
# Unnamed: 4                                                   SA4 code
# Unnamed: 5                                                   SA4 name
# Unnamed: 6                                                   SA3 code
# Unnamed: 7                                                   SA3 name
# Unnamed: 8                                                   SA2 code
# Unnamed: 9                                                   SA2 name
# Unnamed: 10                                           Population_2018
# Unnamed: 11                                           Population_2019
# Unnamed: 12                                                       NaN
# Unnamed: 13                                         Population_growth
# Unnamed: 14                                                         %
# Unnamed: 15                                                       NaN
# Unnamed: 16                                          Natural Increase
# Unnamed: 17                                    Net Internal Migration
# Unnamed: 18                                    Net Overseas Migration
# Unnamed: 19                                                       NaN
# Unnamed: 20                                                       km2
# Unnamed: 21                                               persons/km2
# Name: 6, dtype: object

# %%
#Assigning the row 6 as header:
df.columns = df.iloc[6]
df.head(10)
# Out:
# 6                                           S/T code  S/T name  GCCSA code  \
# 0      3218.0  Regional Population Growth, Australia       NaN         NaN
# 1  Released at 11.30am (Canberra time) 25 March 2020       NaN         NaN
# 2  Table 2. Estimated Resident Population, Statis...       NaN         NaN
# 3                                                NaN       NaN         NaN
# 4                                                NaN       NaN         NaN
# 5                                                NaN       NaN         NaN
# 6                                           S/T code  S/T name  GCCSA code
# 7                                                NaN       NaN         NaN
# 8                                                  2  Victoria       2RVIC
# 9                                                  2  Victoria       2RVIC
#
# 6    GCCSA name  SA4 code  SA4 name  SA3 code  SA3 name   SA2 code   SA2 name  \
# 0           NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 1           NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 2           NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 3           NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 4           NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 5           NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 6    GCCSA name  SA4 code  SA4 name  SA3 code  SA3 name   SA2 code   SA2 name
# 7           NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 8  Rest of Vic.       201  Ballarat     20101  Ballarat  201011001  Alfredton
# 9  Rest of Vic.       201  Ballarat     20101  Ballarat  201011002   Ballarat
#
# 6  ... NaN  Population_growth    % NaN  \
# 0  ... NaN                NaN  NaN NaN
# 1  ... NaN                NaN  NaN NaN
# 2  ... NaN                NaN  NaN NaN
# 3  ... NaN                NaN  NaN NaN
# 4  ... NaN         ERP change  NaN NaN
# 5  ... NaN          2018-2019  NaN NaN
# 6  ... NaN  Population_growth    % NaN
# 7  ... NaN                NaN  NaN NaN
# 8  ... NaN                778  5.9 NaN
# 9  ... NaN                 50  0.4 NaN
#
# 6                         Natural Increase  Net Internal Migration  \
# 0                                      NaN                     NaN
# 1                                      NaN                     NaN
# 2                                      NaN                     NaN
# 3                                      NaN                     NaN
# 4  Components of population change 2018-19                     NaN
# 5                         Natural increase  Net internal migration
# 6                         Natural Increase  Net Internal Migration
# 7                                      NaN                     NaN
# 8                                      127                     582
# 9                                      -33                      -2
#
# 6  Net Overseas Migration NaN   km2              persons/km2
# 0                     NaN NaN   NaN                      NaN
# 1                     NaN NaN   NaN                      NaN
# 2                     NaN NaN   NaN                      NaN
# 3                     NaN NaN   NaN                      NaN
# 4                     NaN NaN   NaN                      NaN
# 5  Net overseas migration NaN  Area  Population density 2019
# 6  Net Overseas Migration NaN   km2              persons/km2
# 7                     NaN NaN   NaN                      NaN
# 8                      69 NaN  52.7                    266.9
# 9                      85 NaN  12.4                    987.6
#
# [10 rows x 22 columns]

# %%
#Dropping all unnessary rows:
new_df = df.iloc[8:470,:]
#Reset the index:
df2 = new_df.reset_index(drop=True)
df2
# Out:
# 6   S/T code  S/T name GCCSA code    GCCSA name SA4 code  \
# 0          2  Victoria      2RVIC  Rest of Vic.      201
# 1          2  Victoria      2RVIC  Rest of Vic.      201
# 2          2  Victoria      2RVIC  Rest of Vic.      201
# 3          2  Victoria      2RVIC  Rest of Vic.      201
# 4          2  Victoria      2RVIC  Rest of Vic.      201
# ..       ...       ...        ...           ...      ...
# 457        2  Victoria      2RVIC  Rest of Vic.      217
# 458        2  Victoria      2RVIC  Rest of Vic.      217
# 459        2  Victoria      2RVIC  Rest of Vic.      217
# 460        2  Victoria      2RVIC  Rest of Vic.      217
# 461        2  Victoria      2RVIC  Rest of Vic.      217
#
# 6                      SA4 name SA3 code             SA3 name   SA2 code  \
# 0                      Ballarat    20101             Ballarat  201011001
# 1                      Ballarat    20101             Ballarat  201011002
# 2                      Ballarat    20101             Ballarat  201011003
# 3                      Ballarat    20101             Ballarat  201011004
# 4                      Ballarat    20101             Ballarat  201011005
# ..                          ...      ...                  ...        ...
# 457  Warrnambool and South West    21703  Colac - Corangamite  217031476
# 458  Warrnambool and South West    21704          Warrnambool  217041477
# 459  Warrnambool and South West    21704          Warrnambool  217041478
# 460  Warrnambool and South West    21704          Warrnambool  217041479
# 461  Warrnambool and South West    21704          Warrnambool  217041480
#
# 6               SA2 name  ... NaN Population_growth    % NaN Natural Increase  \
# 0              Alfredton  ... NaN               778  5.9 NaN              127
# 1               Ballarat  ... NaN                50  0.4 NaN              -33
# 2       Ballarat - North  ... NaN               310  1.3 NaN               83
# 3       Ballarat - South  ... NaN               204  0.8 NaN              109
# 4              Buninyong  ... NaN               128  1.7 NaN               33
# ..                   ...  ...  ..               ...  ...  ..              ...
# 457                Otway  ... NaN                29  0.8 NaN               -1
# 458         Moyne - East  ... NaN                16  0.2 NaN               25
# 459         Moyne - West  ... NaN                65  0.7 NaN               24
# 460  Warrnambool - North  ... NaN               253  1.2 NaN               93
# 461  Warrnambool - South  ... NaN                53  0.4 NaN              -14
#
# 6    Net Internal Migration Net Overseas Migration NaN     km2  persons/km2
# 0                       582                     69 NaN    52.7        266.9
# 1                        -2                     85 NaN    12.4        987.6
# 2                       134                     93 NaN    92.4        264.8
# 3                       -58                    153 NaN    32.9          779
# 4                        49                     46 NaN    51.6        149.5
# ..                      ...                    ...  ..     ...          ...
# 457                      -4                     34 NaN  1505.9          2.4
# 458                     -29                     20 NaN  3275.8            2
# 459                      -4                     45 NaN  2037.8          4.8
# 460                       1                    159 NaN    62.4        356.1
# 461                     -80                    147 NaN   120.2        110.6
#
# [462 rows x 22 columns]

# %%
#Renaming the column names:
df2.rename(columns = {
                      'km2':'Area(km2)',
                      'persons/km2':'Population Density 2019 (persons/km2)'
                     }, 
           inplace = True) 
df2.head()
# Out:
# 6 S/T code  S/T name GCCSA code    GCCSA name SA4 code  SA4 name SA3 code  \
# 0        2  Victoria      2RVIC  Rest of Vic.      201  Ballarat    20101
# 1        2  Victoria      2RVIC  Rest of Vic.      201  Ballarat    20101
# 2        2  Victoria      2RVIC  Rest of Vic.      201  Ballarat    20101
# 3        2  Victoria      2RVIC  Rest of Vic.      201  Ballarat    20101
# 4        2  Victoria      2RVIC  Rest of Vic.      201  Ballarat    20101
#
# 6  SA3 name   SA2 code          SA2 name  ... NaN Population_growth    % NaN  \
# 0  Ballarat  201011001         Alfredton  ... NaN               778  5.9 NaN
# 1  Ballarat  201011002          Ballarat  ... NaN                50  0.4 NaN
# 2  Ballarat  201011003  Ballarat - North  ... NaN               310  1.3 NaN
# 3  Ballarat  201011004  Ballarat - South  ... NaN               204  0.8 NaN
# 4  Ballarat  201011005         Buninyong  ... NaN               128  1.7 NaN
#
# 6 Natural Increase  Net Internal Migration Net Overseas Migration NaN  \
# 0              127                     582                     69 NaN
# 1              -33                      -2                     85 NaN
# 2               83                     134                     93 NaN
# 3              109                     -58                    153 NaN
# 4               33                      49                     46 NaN
#
# 6 Area(km2)  Population Density 2019 (persons/km2)
# 0      52.7                                  266.9
# 1      12.4                                  987.6
# 2      92.4                                  264.8
# 3      32.9                                    779
# 4      51.6                                  149.5
#
# [5 rows x 22 columns]

# %%
#Selecting columns needed:
df3 = df2[['SA4 code','SA4 name','SA3 code','SA3 name','SA2 code','SA2 name',
          'Population_2018', 'Population_2019', "Natural Increase","Net Internal Migration", 'Net Overseas Migration',
          'Area(km2)','Population Density 2019 (persons/km2)']]
df3.head()
# Out:
# 6 SA4 code  SA4 name SA3 code  SA3 name   SA2 code          SA2 name  \
# 0      201  Ballarat    20101  Ballarat  201011001         Alfredton
# 1      201  Ballarat    20101  Ballarat  201011002          Ballarat
# 2      201  Ballarat    20101  Ballarat  201011003  Ballarat - North
# 3      201  Ballarat    20101  Ballarat  201011004  Ballarat - South
# 4      201  Ballarat    20101  Ballarat  201011005         Buninyong
#
# 6 Population_2018 Population_2019 Natural Increase Net Internal Migration  \
# 0           13291           14069              127                    582
# 1           12175           12225              -33                     -2
# 2           24147           24457               83                    134
# 3           25390           25594              109                    -58
# 4            7584            7712               33                     49
#
# 6 Net Overseas Migration Area(km2) Population Density 2019 (persons/km2)
# 0                     69      52.7                                 266.9
# 1                     85      12.4                                 987.6
# 2                     93      92.4                                 264.8
# 3                    153      32.9                                   779
# 4                     46      51.6                                 149.5

# %%
#Checking the number of rows:
df3.count()
# Out:
# 6
# SA4 code                                 462
# SA4 name                                 462
# SA3 code                                 462
# SA3 name                                 462
# SA2 code                                 462
# SA2 name                                 462
# Population_2018                          462
# Population_2019                          462
# Natural Increase                         462
# Net Internal Migration                   462
# Net Overseas Migration                   462
# Area(km2)                                462
# Population Density 2019 (persons/km2)    462
# dtype: int64

# %%
# Removing any row with a NULL value: 
df4 = df3.dropna(how="any")
df4.count()
# Out:
# 6
# SA4 code                                 462
# SA4 name                                 462
# SA3 code                                 462
# SA3 name                                 462
# SA2 code                                 462
# SA2 name                                 462
# Population_2018                          462
# Population_2019                          462
# Natural Increase                         462
# Net Internal Migration                   462
# Net Overseas Migration                   462
# Area(km2)                                462
# Population Density 2019 (persons/km2)    462
# dtype: int64

# %%
#Checking the types of data:
df4.dtypes
# Out:
# 6
# SA4 code                                 object
# SA4 name                                 object
# SA3 code                                 object
# SA3 name                                 object
# SA2 code                                 object
# SA2 name                                 object
# Population_2018                          object
# Population_2019                          object
# Natural Increase                         object
# Net Internal Migration                   object
# Net Overseas Migration                   object
# Area(km2)                                object
# Population Density 2019 (persons/km2)    object
# dtype: object

# %%
#Converting the relevant columns to either integer or float:
df4['Population_2018']= df4['Population_2018'].astype(int)  
df4['Population_2019']= df4['Population_2019'].astype(int)  
df4['Natural Increase']= df4['Natural Increase'].astype(int)
df4['Net Internal Migration']= df4['Net Internal Migration'].astype(int)
df4['Net Overseas Migration']= df4['Net Overseas Migration'].astype(int)
df4['Area(km2)']= df4['Area(km2)'].astype(float)
df4['Population Density 2019 (persons/km2)']= df4['Population Density 2019 (persons/km2)'].astype(float)

df4.dtypes
# Out:
# 6
# SA4 code                                  object
# SA4 name                                  object
# SA3 code                                  object
# SA3 name                                  object
# SA2 code                                  object
# SA2 name                                  object
# Population_2018                            int32
# Population_2019                            int32
# Natural Increase                           int32
# Net Internal Migration                     int32
# Net Overseas Migration                     int32
# Area(km2)                                float64
# Population Density 2019 (persons/km2)    float64
# dtype: object

# %% [markdown]
# ## Exploratory analysis

# %%
#Using df describe to check the quality of the data:
df4.describe()
# Out:
# 6      Population_2018  Population_2019  Natural Increase  \
# count       462.000000       462.000000        462.000000
# mean      13987.054113     14277.140693         80.829004
# std        7703.609591      7999.803736        113.174059
# min           0.000000         0.000000       -126.000000
# 25%        8134.000000      8316.500000          9.000000
# 50%       13333.500000     13614.000000         57.000000
# 75%       19216.500000     19631.250000        115.500000
# max       49247.000000     51894.000000        960.000000
#
# 6      Net Internal Migration  Net Overseas Migration     Area(km2)  \
# count              462.000000              462.000000    462.000000
# mean                26.402597              182.854978    492.415152
# std                493.585582              270.885858   1645.782889
# min              -1340.000000                0.000000      1.300000
# 25%               -138.750000               34.500000      6.025000
# 50%                -27.000000              108.000000     14.500000
# 75%                 55.000000              238.250000    129.175000
# max               6503.000000             3445.000000  21569.500000
#
# 6      Population Density 2019 (persons/km2)
# count                             462.000000
# mean                             1629.277273
# std                              2080.589639
# min                                 0.000000
# 25%                                60.200000
# 50%                              1009.500000
# 75%                              2543.075000
# max                             21905.400000

# %% [markdown]
# As the minimum values for population 2018 and 2019, population density and net overseas migration are at 0, we will look into the reason behind this.

# %%
#Checking the minimum values by sorting the Population 2019 in ascending order:
df4_sort = df4.sort_values(by=["Population_2019"])
df4_sort.head(10)
# Out:
# 6   SA4 code                 SA4 name SA3 code                SA3 name  \
# 193      208  Melbourne - Inner South    20803                Kingston
# 82       205      Latrobe - Gippsland    20502        Gippsland - East
# 235      210   Melbourne - North West    21001                  Keilor
# 79       205      Latrobe - Gippsland    20502        Gippsland - East
# 126      206        Melbourne - Inner    20604          Melbourne City
# 91       205      Latrobe - Gippsland    20503  Gippsland - South West
# 98       205      Latrobe - Gippsland    20505              Wellington
# 185      208  Melbourne - Inner South    20803                Kingston
# 119      206        Melbourne - Inner    20604          Melbourne City
# 87       205      Latrobe - Gippsland    20503  Gippsland - South West
#
# 6     SA2 code               SA2 name  Population_2018  Population_2019  \
# 193  208031192      Moorabbin Airport                0                0
# 82   205021083              Lake King                0                0
# 235  210011227       Essendon Airport                0                0
# 79   205021080            Alps - East                3                3
# 126  206041127         West Melbourne                3                3
# 91   205031092     Wilsons Promontory               13               13
# 98   205051099            Alps - West               24               24
# 185  208031184               Braeside               60               60
# 119  206041120  Flemington Racecourse               91               91
# 87   205031088          French Island              114              114
#
# 6    Natural Increase  Net Internal Migration  Net Overseas Migration  \
# 193                 0                       0                       0
# 82                  0                       0                       0
# 235                 0                       0                       0
# 79                  0                       0                       0
# 126                 0                       0                       0
# 91                  0                       0                       0
# 98                  0                       0                       0
# 185                 0                       0                       0
# 119                 0                       0                       0
# 87                  0                       0                       0
#
# 6    Area(km2)  Population Density 2019 (persons/km2)
# 193        3.1                                    0.0
# 82        93.9                                    0.0
# 235        3.4                                    0.0
# 79      2071.3                                    0.0
# 126        6.2                                    0.5
# 91       481.5                                    0.0
# 98      2955.7                                    0.0
# 185        9.1                                    6.6
# 119        1.7                                   53.2
# 87       170.2                                    0.7

# %% [markdown]
# These 10 suburbs with the lowest population numbers are interesting. However the data seems relevant for all them.
# Indeed it makes sense, there isn't anyone living in Essendon Airport or Moorabin airport. There are very zero or few people living in National parks like Lake King or Wilsons Promontory. The West Melbourne area is mostly taken by the port and therefore there isn't any space for people to live there.

# %%
#Looking at the correlation between population and population density:
x_axis = df4["Population_2019"]
y_axis = df4["Population Density 2019 (persons/km2)"]
plt.scatter(x_axis,y_axis)
#plt.plot(x_axis,regress_values,"r-")
#plt.annotate(line_eq,(2500,50),fontsize=10,color="red")
plt.xlabel("Count of population in 2019")
plt.ylabel("Population density (persons/km2)")
plt.title("Population vs Population density in 2019")
plt.show()

# %% [markdown]
# As there are a few outliers, we will check the top 10 suburbs with the highest density to ensure the data is relevant.

# %%
#Checking the minimum values by sorting the Population 2019 in ascending order:
df4_sort = df4.sort_values(by=["Population Density 2019 (persons/km2)"], ascending = False)
df4_sort.head(10)
# Out:
# 6   SA4 code           SA4 name SA3 code            SA3 name   SA2 code  \
# 121      206  Melbourne - Inner    20604      Melbourne City  206041122
# 116      206  Melbourne - Inner    20604      Melbourne City  206041117
# 136      206  Melbourne - Inner    20606  Stonnington - West  206061137
# 140      206  Melbourne - Inner    20607               Yarra  206071141
# 141      206  Melbourne - Inner    20607               Yarra  206071142
# 125      206  Melbourne - Inner    20604      Melbourne City  206041126
# 122      206  Melbourne - Inner    20604      Melbourne City  206041123
# 132      206  Melbourne - Inner    20605        Port Phillip  206051133
# 133      206  Melbourne - Inner    20605        Port Phillip  206051134
# 135      206  Melbourne - Inner    20606  Stonnington - West  206061136
#
# 6              SA2 name  Population_2018  Population_2019  Natural Increase  \
# 121           Melbourne            49247            51894               235
# 116             Carlton            23261            24692                52
# 136  South Yarra - East            24654            25051               147
# 140         Collingwood            10377            10984                88
# 141             Fitzroy            11726            11903                57
# 125           Southbank            24424            26324               184
# 122     North Melbourne            25367            26459               161
# 132            St Kilda            29886            30447                97
# 133       St Kilda East            18262            18583               153
# 135   Prahran - Windsor            22040            22234                96
#
# 6    Net Internal Migration  Net Overseas Migration  Area(km2)  \
# 121                   -1033                    3445        2.4
# 116                    -651                    2030        1.8
# 136                    -433                     683        2.5
# 140                     186                     333        1.3
# 141                    -155                     275        1.4
# 125                    1007                     709        3.1
# 122                    -284                    1215        3.2
# 132                    -385                     849        3.9
# 133                    -185                     353        2.4
# 135                    -368                     466        2.9
#
# 6    Population Density 2019 (persons/km2)
# 121                                21905.4
# 116                                13578.2
# 136                                 9951.9
# 140                                 8668.6
# 141                                 8637.9
# 125                                 8562.6
# 122                                 8143.2
# 132                                 7804.9
# 133                                 7699.6
# 135                                 7652.6

# %% [markdown]
# We can see the data is relevant as these are the most dense suburbs close to Melbourne CBD.

# %%
#Visualising the population of all suburbs with an histogram
x = df4.hist(column='Population_2019', bins=20, grid=False, figsize=(10,5), color='#86bf91', zorder=2, rwidth=0.9)
#Titles and axis
plt.title("Population 2019")
plt.ylabel("Number of suburbs")
plt.xlabel("Population 2019")
#Showing the histogram
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Load into the database

# %% [markdown]
# To work with the SQL database the columns names need to be low case and without any space, therefore we are renaming columns accordingly.

# %%
#Rename some columns:
df4 = df4.rename(columns={ 
                        "SA2 code": "sa2_code",
                        "SA2 name": "sa2_name",
                        "SA3 code": "sa3_code",
                        "SA3 name": "sa3_name",
                        "SA4 code": "sa4_code",
                        "SA4 name": "sa4_name",
                        "Population_2018" : "population_2018",
                        "Population_2019" : "population_2019",
                        "Natural Increase" : "natural_increase",
                        "Net Internal Migration" : "net_internal_migration",
                        "Net Overseas Migration" : "net_overseas_migration",
                        "Area(km2)" : "area_size",
                        "Population Density 2019 (persons/km2)": "population_density_2019"             
                       })

df4.head()
# Out:
# 6 sa4_code  sa4_name sa3_code  sa3_name   sa2_code          sa2_name  \
# 0      201  Ballarat    20101  Ballarat  201011001         Alfredton
# 1      201  Ballarat    20101  Ballarat  201011002          Ballarat
# 2      201  Ballarat    20101  Ballarat  201011003  Ballarat - North
# 3      201  Ballarat    20101  Ballarat  201011004  Ballarat - South
# 4      201  Ballarat    20101  Ballarat  201011005         Buninyong
#
# 6  population_2018  population_2019  natural_increase  net_internal_migration  \
# 0            13291            14069               127                     582
# 1            12175            12225               -33                      -2
# 2            24147            24457                83                     134
# 3            25390            25594               109                     -58
# 4             7584             7712                33                      49
#
# 6  net_overseas_migration  area_size  population_density_2019
# 0                      69       52.7                    266.9
# 1                      85       12.4                    987.6
# 2                      93       92.4                    264.8
# 3                     153       32.9                    779.0
# 4                      46       51.6                    149.5

# %%
# Connect to PostgresSQL database 
population_connection_string = "postgres:<password>@localhost:5432/population_db"
engine = create_engine(f'postgresql://{population_connection_string}')

# %%
# Confirm table names
engine.table_names()
# Out:
# ['households_type', 'population_growth']

# %%
# Load master dataframe to database using pandas
df4.to_sql(name='population_growth', con=engine, if_exists='append', index=False)

# %%
# Query database to check if loading is successful
pd.read_sql_query('select * from population_growth', con=engine).head()
# Out:
#     sa2_code          sa2_name sa3_code  sa3_name sa4_code  sa4_name  \
# 0  201011001         Alfredton    20101  Ballarat      201  Ballarat
# 1  201011002          Ballarat    20101  Ballarat      201  Ballarat
# 2  201011003  Ballarat - North    20101  Ballarat      201  Ballarat
# 3  201011004  Ballarat - South    20101  Ballarat      201  Ballarat
# 4  201011005         Buninyong    20101  Ballarat      201  Ballarat
#
#    population_2018  population_2019  natural_increase  net_internal_migration  \
# 0            13291            14069               127                     582
# 1            12175            12225               -33                      -2
# 2            24147            24457                83                     134
# 3            25390            25594               109                     -58
# 4             7584             7712                33                      49
#
#    net_overseas_migration  area_size  population_density_2019
# 0                      69       52.7                    266.9
# 1                      85       12.4                    987.6
# 2                      93       92.4                    264.8
# 3                     153       32.9                    779.0
# 4                      46       51.6                    149.5

# %%
# Query database to check population for sa3_code '20501'
pd.read_sql_query("select sa3_code, sa3_name, sa2_code, sa2_name, population_2018, population_2019 from population_growth where sa3_code = '20501';", con=engine).head()
# Out:
#   sa3_code sa3_name   sa2_code              sa2_name  population_2018  \
# 0    20501  Baw Baw  205011076                Drouin            17777
# 1    20501  Baw Baw  205011077  Mount Baw Baw Region             6147
# 2    20501  Baw Baw  205011078      Trafalgar (Vic.)             8035
# 3    20501  Baw Baw  205011079              Warragul            20148
#
#    population_2019
# 0            18453
# 1             6191
# 2             8078
# 3            20764
